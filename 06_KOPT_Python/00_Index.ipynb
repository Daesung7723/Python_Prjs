# %% [markdown]
# # 파이썬 코딩 학습 전체 목차 🐍
#
# ## PART 1: 파이썬 기초 다지기 (왕초보)
#
# ### Chapter 1: 프로그래밍과 파이썬 소개
# - 프로그래밍이란 무엇일까?
# - 파이썬의 특징과 장점
# - 파이썬 개발 환경 설치하기 (VS Code)
# - 첫 파이썬 코드: Hello, World! 출력하기
#
# ### Chapter 2: 변수와 기본 자료형
# - 데이터의 타입: 숫자형, 문자열, 불리언
# - 변수의 선언과 사용
# - 기본 자료형의 특징과 활용
#
# ### Chapter 3: 데이터 묶음, 자료구조
# - 순서가 있는 데이터: 리스트(List)
# - 변경할 수 없는 데이터: 튜플(Tuple)
# - 키-값 쌍으로 이루어진 데이터: 딕셔너리(Dictionary)
# - 중복을 허용하지 않는 데이터: 세트(Set)
#
# ### Chapter 4: 코드의 흐름 제어하기
# - 조건에 따라 실행하는 if 문
# - 반복 실행하는 for 문
# - 특정 조건까지 반복하는 while 문
#
# ### Chapter 5: 코드 재사용을 위한 함수
# - 함수란 무엇일까?
# - 함수 만들고 사용하기 (정의와 호출)
# - 값을 전달하는 매개변수(Parameter)
# - 결과를 돌려주는 반환값(Return)
#
# ## PART 2: 파이썬 중급으로 레벨 업!
#
# ### Chapter 6: 객체 지향 프로그래밍 (OOP)
# - **클래스(Class)**와 **객체(Object)**의 개념
# - 나만의 클래스 만들기
# - 상속, 다형성 등 OOP의 핵심 개념
#
# ### Chapter 7: 모듈과 패키지
# - 다른 사람이 만든 코드 가져오기: import
# - 자주 쓰는 유용한 표준 라이브러리 (math, random, datetime)
# - 외부 라이브러리 설치하고 사용하기 (pip)
#
# ### Chapter 8: 파일 다루기
# - 텍스트 파일 읽고 쓰기
# - 데이터를 저장하는 CSV 파일 다루기
#
# ### Chapter 9: 오류 처리하기
# - 프로그램 오류(에러)의 종류
# - 예상치 못한 오류를 처리하는 try-except 구문
#
# ## PART 3: 파이썬 실전 활용
#
# ### Chapter 10: 데이터 분석 맛보기
# - Numpy, Pandas 라이브러리 소개
# - 데이터 정제 및 간단한 분석
#
# ### Chapter 11: 웹 스크레이핑 (크롤링)
# - 웹 페이지 정보 자동으로 가져오기
# - BeautifulSoup, Selenium 라이브러리 활용
#
# ### Chapter 12: 간단한 웹 개발
# - Flask 프레임워크로 나만의 웹사이트 만들기
#
# ### Chapter 13: 업무 자동화
# - 엑셀, 이메일, 파일 정리 등 반복 작업 자동화하기
